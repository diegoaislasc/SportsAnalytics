# %%
import sys
sys.path.append("../src")

import ScraperFC as sfc  # LEAVE THIS!
ss = sfc.Sofascore()

# %%
match_dicts = ss.get_match_dicts('21/22', "EPL")

# %%
match_dicts[0]
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1176642,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 21/22',
#   'year': '21/22',
#   'editor': False,
#   'id': 37036},
#  'roundInfo': {'round': 36},
#  'customId': 'JsR',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 1,
#  'homeTeam': {'name': 'Arsenal',
#   'slug': 'arsenal',
#   'shortName': 'Arsenal',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 2857187,
#   'nameCode': 'ARS',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 42,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#cc0000',
#    'secondary': '#ffffff',
#    'text': '#ffffff'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'ارسنال',
#     'ru': 'Арсенал',
#     'hi': 'आर्सेनल',
#     'bn': 'আর্সেনাল'},
#    'shortNameTranslation': {}}},
#  'awayTeam': {'name': 'Leeds United',
#   'slug': 'leeds-united',
#   'shortName': 'Leeds',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 218307,
#   'nameCode': 'LEE',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 34,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#ffffff',
#    'secondary': '#1d4189',
#    'text': '#1d4189'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'ليدز يونايتد',
#     'ru': 'Лидс',
#     'hi': 'लीड्स यूनाइटेड',
#     'bn': 'লিডস'},
#    'shortNameTranslation': {'ar': 'ليدز', 'hi': 'लीड्स'}}},
#  'homeScore': {'current': 2,
#   'display': 2,
#   'period1': 2,
#   'period2': 0,
#   'normaltime': 2},
#  'awayScore': {'current': 1,
#   'display': 1,
#   'period1': 0,
#   'period2': 1,
#   'normaltime': 1},
#  'coverage': 1,
#  'time': {'injuryTime1': 4,
#   'injuryTime2': 3,
#   'currentPeriodStartTimestamp': 1652018731},
#  'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#   'changeTimestamp': 1652021661},
#  'hasGlobalHighlights': False,
#  'hasXg': True,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 9576454,
#  'awayRedCards': 1,
#  'slug': 'arsenal-leeds-united',
#  'startTimestamp': 1652014800,
#  'finalResultOnly': False,
#  'feedLocked': True,
#  'isEditor': False}

# %%
match_dict =  ss.get_match_dict(9576454)
match_dict
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1177269,
#    'hasRounds': True,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'competitionType': 1,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 21/22',
#   'year': '21/22',
#   'editor': False,
#   'id': 37036},
#  'roundInfo': {'round': 36},
#  'customId': 'JsR',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 1,
#  'attendance': 60108,
#  'venue': {'city': {'name': 'London'},
#   'venueCoordinates': {'latitude': 51.55504, 'longitude': -0.1084},
#   'hidden': False,
#   'slug': 'emirates-stadium',
#   'name': 'Emirates Stadium',
#   'capacity': 60704,
#   'id': 624,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'ملعب الإمارات',
#     'hi': 'एमिरेट्स स्टेडियम',
#     'bn': 'এমিরেটস স্টেডিয়াম'},
#    'shortNameTranslation': {}},
#   'stadium': {'name': 'Emirates Stadium', 'capacity': 60704}},
#  'referee': {'name': 'Chris Kavanagh',
#   'slug': 'chris-kavanagh',
#   'yellowCards': 1288,
#   'redCards': 29,
#   'yellowRedCards': 13,
#   'games': 352,
#   'sport': {'id': 1, 'slug': 'football', 'name': 'Football'},
#   'id': 107059,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'كريس كافاناغ',
#     'hi': 'क्रिस कवानाघ',
#     'bn': 'ক্রিস কাভানাঘ'},
#    'shortNameTranslation': {}}},
#  'homeTeam': {'name': 'Arsenal',
#   'slug': 'arsenal',
#   'shortName': 'Arsenal',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 2852196,
#   'manager': {'name': 'Mikel Arteta',
#    'slug': 'mikel-arteta',
#    'shortName': 'M. Arteta',
#    'id': 794075,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ميكيل أرتيتا',
#      'hi': 'मिकेल आर्टेटा',
#      'bn': 'মিকেল আর্তেতা'},
#     'shortNameTranslation': {'ar': 'م. أرتيتا',
#      'hi': 'एम. आर्टेटा',
#      'bn': 'এম. আরতেতা'}}},
#   'venue': {'city': {'name': 'London'},
#    'venueCoordinates': {'latitude': 51.55504, 'longitude': -0.1084},
#    'hidden': False,
#    'slug': 'emirates-stadium',
#    'name': 'Emirates Stadium',
#    'capacity': 60704,
#    'id': 624,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ملعب الإمارات',
#      'hi': 'एमिरेट्स स्टेडियम',
#      'bn': 'এমিরেটস স্টেডিয়াম'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'Emirates Stadium', 'capacity': 60704}},
#   'nameCode': 'ARS',
#   'class': 4,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 42,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Arsenal',
#   'subTeams': [],
#   'teamColors': {'primary': '#cc0000',
#    'secondary': '#ffffff',
#    'text': '#ffffff'},
#   'foundationDateTimestamp': -2627164800,
#   'fieldTranslations': {'nameTranslation': {'ar': 'ارسنال',
#     'ru': 'Арсенал',
#     'hi': 'आर्सेनल',
#     'bn': 'আর্সেনাল'},
#    'shortNameTranslation': {}},
#   'timeActive': []},
#  'awayTeam': {'name': 'Leeds United',
#   'slug': 'leeds-united',
#   'shortName': 'Leeds',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 218724,
#   'manager': {'name': 'Daniel Farke',
#    'slug': 'daniel-farke',
#    'shortName': 'D. Farke',
#    'id': 265307,
#    'country': {'alpha2': 'DE',
#     'alpha3': 'DEU',
#     'name': 'Germany',
#     'slug': 'germany'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'دانييل فاركي',
#      'hi': 'डैनियल फ़ार्के',
#      'bn': 'ড্যানিয়েল ফারকে'},
#     'shortNameTranslation': {'ar': 'د. فاركي',
#      'hi': 'डी. फ़ार्के',
#      'bn': 'ডি. ফারকে'}}},
#   'venue': {'city': {'name': 'Leeds'},
#    'venueCoordinates': {'latitude': 53.775644, 'longitude': -1.575748},
#    'hidden': False,
#    'slug': 'elland-road',
#    'name': 'Elland Road',
#    'capacity': 37890,
#    'id': 2223,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'إيلاند رود',
#      'hi': 'एलैंड रोड',
#      'bn': 'এল্যান্ড রোড'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'Elland Road', 'capacity': 37890}},
#   'nameCode': 'LEE',
#   'class': 0,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 34,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Leeds United',
#   'subTeams': [],
#   'teamColors': {'primary': '#ffffff',
#    'secondary': '#1d4189',
#    'text': '#1d4189'},
#   'foundationDateTimestamp': -1584489600,
#   'fieldTranslations': {'nameTranslation': {'ar': 'ليدز يونايتد',
#     'ru': 'Лидс',
#     'hi': 'लीड्स यूनाइटेड',
#     'bn': 'লিডস'},
#    'shortNameTranslation': {'ar': 'ليدز', 'hi': 'लीड्स'}},
#   'timeActive': []},
#  'homeScore': {'current': 2,
#   'display': 2,
#   'period1': 2,
#   'period2': 0,
#   'normaltime': 2},
#  'awayScore': {'current': 1,
#   'display': 1,
#   'period1': 0,
#   'period2': 1,
#   'normaltime': 1},
#  'coverage': 1,
#  'time': {'injuryTime1': 4,
#   'injuryTime2': 3,
#   'currentPeriodStartTimestamp': 1652018731},
#  'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#   'changeTimestamp': 1652021661},
#  'hasGlobalHighlights': False,
#  'hasXg': True,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 9576454,
#  'awayRedCards': 1,
#  'defaultPeriodCount': 2,
#  'defaultPeriodLength': 45,
#  'defaultOvertimeLength': 15,
#  'slug': 'arsenal-leeds-united',
#  'currentPeriodStartTimestamp': 1652018731,
#  'startTimestamp': 1652014800,
#  'finalResultOnly': False,
#  'feedLocked': True,
#  'seasonStatisticsType': 'overall',
#  'showTotoPromo': True,
#  'isEditor': False}

# %%
# Define the league and season parameters
# Note: Ensure 'EPL' and '23/24' match the expected format for ScraperFC's Sofascore module
LEAGUE = 'EPL'
SEASON = '21/22'

try:
    # 1. Retrieve match dictionaries for the entire season
    # This returns a list of dictionaries, where each dictionary represents a match
    match_dicts = ss.get_match_dicts(year=SEASON, league=LEAGUE)
    
    print(f"Retrieved {len(match_dicts)} match records.")

    # 2. Extract match IDs
    # Iterate through the list and extract the 'id' from each match dictionary
    match_ids = [match['id'] for match in match_dicts if 'id' in match]

    print(f"Extracted {len(match_ids)} match IDs.")
    
    # Optional: Display the first 5 IDs to verify
    print("Sample Match IDs:", match_ids[:5])
    
    # Optional: Check if the specific ID from your example exists in the list
    target_id = 9576454
    if target_id in match_ids:
        print(f"Target match ID {target_id} found in the dataset.")
    else:
        print(f"Target match ID {target_id} NOT found. (Check season/league parameters)")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Retrieved 415 match records.
# Extracted 415 match IDs.
# Sample Match IDs: [9576454, 9576340, 10236821, 10236820, 10236818]
# Target match ID 9576454 found in the dataset.

# %%
match_ids
# Out:
# [9576454,
#  9576340,
#  10236821,
#  10236820,
#  10236818,
#  10236824,
#  10277713,
#  10236815,
#  9576298,
#  9576462,
#  9576453,
#  9576362,
#  9576433,
#  9576310,
#  9576464,
#  9576356,
#  9576430,
#  10236819,
#  10236823,
#  10236816,
#  9576353,
#  9576312,
#  9576354,
#  9576355,
#  9576218,
#  9576311,
#  9576308,
#  9576220,
#  9576352,
#  9576299,
#  10196713,
#  9576258,
#  9576273,
#  9576267,
#  9576277,
#  9576263,
#  9576428,
#  9576262,
#  9576443,
#  9576266,
#  9576265,
#  9576293,
#  9576434,
#  9576358,
#  9576275,
#  9576318,
#  9576269,
#  9576272,
#  9576360,
#  9576335,
#  9576429,
#  9576283,
#  9576330,
#  9576336,
#  9576321,
#  9576343,
#  9576322,
#  9576357,
#  9576344,
#  9576331,
#  9576327,
#  9576239,
#  9576315,
#  9576241,
#  10196719,
#  9576280,
#  9576242,
#  9576285,
#  9576245,
#  9576284,
#  9576431,
#  9576281,
#  9576244,
#  9576452,
#  9576282,
#  9576304,
#  9576296,
#  9576346,
#  9576435,
#  9576291,
#  9576347,
#  9576294,
#  9576303,
#  9576279,
#  9576348,
#  10196718,
#  10196717,
#  10196711,
#  10196712,
#  10196714,
#  9576461,
#  10144887,
#  9576337,
#  9576448,
#  9576426,
#  9576325,
#  9576249,
#  9576444,
#  9576252,
#  9576253,
#  9576212,
#  9576250,
#  10144879,
#  10144875,
#  10144888,
#  9576425,
#  9576261,
#  9576328,
#  9576257,
#  9576256,
#  9576246,
#  9576235,
#  9576248,
#  9576338,
#  9576236,
#  9576320,
#  9576234,
#  9576447,
#  9576306,
#  9576238,
#  9576459,
#  9576301,
#  9576223,
#  10114688,
#  10114687,
#  10114693,
#  10114694,
#  9576208,
#  9576445,
#  9576228,
#  9576307,
#  9576224,
#  9576199,
#  9576460,
#  9576231,
#  9576201,
#  9576233,
#  10131311,
#  9576287,
#  9576202,
#  9576213,
#  9576288,
#  9576200,
#  9576418,
#  9576292,
#  9576302,
#  9576215,
#  9576205,
#  10144889,
#  10144893,
#  9576332,
#  9576334,
#  10085333,
#  9576351,
#  9576323,
#  9576359,
#  9576345,
#  9576317,
#  9576326,
#  9576341,
#  9576290,
#  9576289,
#  9576432,
#  9576449,
#  9576314,
#  9576319,
#  9576329,
#  9576309,
#  9576463,
#  9576295,
#  9576300,
#  9576305,
#  10098608,
#  9576222,
#  9576210,
#  9576420,
#  9576226,
#  9576227,
#  9576211,
#  9576421,
#  9576103,
#  9576174,
#  9576446,
#  9576392,
#  9576123,
#  10045752,
#  10045753,
#  10045754,
#  9576268,
#  9576278,
#  9576349,
#  9576316,
#  9576350,
#  9576427,
#  9576274,
#  9576361,
#  9576342,
#  9576450,
#  10054000,
#  9576438,
#  10065225,
#  10054009,
#  9576363,
#  9576324,
#  9576451,
#  9576440,
#  9576333,
#  9576439,
#  9576339,
#  9576297,
#  9576378,
#  9576181,
#  9576096,
#  9576254,
#  9576093,
#  9576172,
#  9576146,
#  9576370,
#  9576092,
#  9576387,
#  9576286,
#  9576366,
#  9576381,
#  9576390,
#  9576182,
#  9576118,
#  9576221,
#  9576225,
#  9576191,
#  9576196,
#  9576144,
#  9576395,
#  9576192,
#  9576194,
#  9576112,
#  9576271,
#  9576416,
#  9576171,
#  9576415,
#  9576396,
#  9576122,
#  9576255,
#  9576379,
#  9576270,
#  9576078,
#  9576380,
#  9576111,
#  9576086,
#  9576139,
#  9576107,
#  9576179,
#  9576203,
#  9576469,
#  9576176,
#  9576405,
#  9576247,
#  9576413,
#  9576407,
#  9576108,
#  9576105,
#  9576104,
#  9576377,
#  9576110,
#  9576237,
#  9576393,
#  9576410,
#  9576158,
#  9576097,
#  9576091,
#  9576094,
#  9576264,
#  9576214,
#  9576276,
#  9576142,
#  9576106,
#  9576128,
#  9576082,
#  9576084,
#  9576204,
#  9576090,
#  9576071,
#  9576167,
#  9576083,
#  9576424,
#  9576155,
#  9576099,
#  9576178,
#  9576175,
#  9576206,
#  9576402,
#  9576088,
#  9576400,
#  9576367,
#  9576207,
#  9576372,
#  9576375,
#  9576095,
#  9576079,
#  9576369,
#  9576089,
#  9576422,
#  9576113,
#  9576373,
#  9576232,
#  9576117,
#  9576470,
#  9576098,
#  9576183,
#  9576423,
#  9576072,
#  9576186,
#  9576169,
#  9576140,
#  9576070,
#  9576134,
#  9576130,
#  9576129,
#  9576216,
#  9576401,
#  9576137,
#  9576153,
#  9576125,
#  9576141,
#  9576180,
#  9576419,
#  9576217,
#  9576399,
#  9576133,
#  9576067,
#  9576068,
#  9576195,
#  9576163,
#  9576116,
#  9576157,
#  9576384,
#  9576409,
#  9576411,
#  9576478,
#  9576371,
#  9576127,
#  9576124,
#  9576376,
#  9576219,
#  9576442,
#  9576109,
#  9576185,
#  9576177,
#  9576136,
#  9576394,
#  9576230,
#  9576368,
#  9576374,
#  9576391,
#  9576480,
#  9576126,
#  9576120,
#  9576385,
#  9576115,
#  9576479,
#  9576121,
#  9576240,
#  9576148,
#  9576190,
#  9576132,
#  9576382,
#  9576085,
#  9576087,
#  9576166,
#  9576173,
#  9576408,
#  9576165,
#  9576135,
#  9576168,
#  9576077,
#  9576114,
#  9576075,
#  9576397,
#  9576189,
#  9576406,
#  9576080,
#  9576156,
#  9576229,
#  9576398,
#  9576251,
#  9576161,
#  9576159,
#  9576243,
#  9576154,
#  9576145,
#  9576417,
#  9576151,
#  9576081,
#  9576162,
#  9576160,
#  9576149,
#  9576403,
#  9576259,
#  9576193,
#  9576414,
#  9576188,
#  9576069,
#  9576143,
#  9576209,
#  9576170,
#  9576187,
#  9576184,
#  9576150,
#  9576076,
#  9576412,
#  9576389,
#  9576260,
#  9576383,
#  9576152,
#  9576386,
#  9576147]

# %%
match_shots = ss.scrape_match_shots(9576454)
match_shots
# Out:
#                                                player  isHome shotType  \
# 0   {'name': 'Rodrigo', 'firstName': '', 'lastName...   False     save
# 1   {'name': 'Kalvin Phillips', 'slug': 'kalvin-ph...   False    block
# 2   {'name': 'Martin Ødegaard', 'slug': 'martin-od...    True     save
# 3   {'name': 'Gabriel Magalhães', 'slug': 'gabriel...    True     miss
# 4   {'name': 'Martin Ødegaard', 'slug': 'martin-od...    True     miss
# 5   {'name': 'Diego Llorente', 'slug': 'diego-llor...   False     goal
# 6   {'name': 'Gabriel Martinelli', 'slug': 'gabrie...    True     miss
# 7   {'name': 'Gabriel Martinelli', 'slug': 'gabrie...    True     miss
# 8   {'name': 'Edward Nketiah', 'firstName': '', 'l...    True    block
# 9   {'name': 'Gabriel Martinelli', 'slug': 'gabrie...    True     save
# 10  {'name': 'Gabriel Magalhães', 'slug': 'gabriel...    True     save
# 11  {'name': 'Granit Xhaka', 'slug': 'granit-xhaka...    True     save
# 12  {'name': 'Martin Ødegaard', 'slug': 'martin-od...    True     save
# 13  {'name': 'Gabriel Martinelli', 'slug': 'gabrie...    True     save
# 14  {'name': 'Takehiro Tomiyasu', 'firstName': '',...    True     miss
# 15  {'name': 'Bukayo Saka', 'slug': 'bukayo-saka',...    True     save
# 16  {'name': 'Cédric Soares', 'firstName': '', 'la...    True     miss
# 17  {'name': 'Edward Nketiah', 'firstName': '', 'l...    True     miss
# 18  {'name': 'Edward Nketiah', 'firstName': '', 'l...    True     goal
# 19  {'name': 'Bukayo Saka', 'slug': 'bukayo-saka',...    True    block
# 20  {'name': 'Edward Nketiah', 'firstName': '', 'l...    True     goal
# 21  {'name': 'Edward Nketiah', 'firstName': '', 'l...    True     miss
#
#     situation               playerCoordinates    bodyPart goalMouthLocation  \
# 0   set-piece   {'x': 6.5, 'y': 57.7, 'z': 0}        head        low-centre
# 1      corner  {'x': 18.2, 'y': 67.8, 'z': 0}  right-foot        low-centre
# 2   free-kick  {'x': 22.4, 'y': 42.9, 'z': 0}   left-foot         high-left
# 3      corner   {'x': 3.1, 'y': 61.8, 'z': 0}        head             right
# 4    assisted  {'x': 15.1, 'y': 49.9, 'z': 0}   left-foot       close-right
# 5      corner   {'x': 2.8, 'y': 59.2, 'z': 0}  right-foot         low-right
# 6    assisted  {'x': 14.5, 'y': 49.9, 'z': 0}  right-foot             right
# 7     regular  {'x': 11.1, 'y': 44.1, 'z': 0}   left-foot        close-high
# 8      corner  {'x': 11.2, 'y': 53.4, 'z': 0}        head        low-centre
# 9    assisted   {'x': 5.7, 'y': 27.4, 'z': 0}  right-foot         high-left
# 10   assisted  {'x': 15.1, 'y': 50.9, 'z': 0}   left-foot        low-centre
# 11   assisted    {'x': 25.8, 'y': 31, 'z': 0}   left-foot         low-right
# 12  free-kick    {'x': 10.3, 'y': 80, 'z': 0}   left-foot        low-centre
# 13   assisted   {'x': 3.1, 'y': 31.8, 'z': 0}   left-foot        low-centre
# 14  set-piece   {'x': 2.4, 'y': 58.1, 'z': 0}        head             right
# 15   assisted  {'x': 12.7, 'y': 68.4, 'z': 0}   left-foot        low-centre
# 16    regular    {'x': 15, 'y': 66.6, 'z': 0}  right-foot        high-right
# 17   assisted   {'x': 2.8, 'y': 58.5, 'z': 0}  right-foot             right
# 18   assisted     {'x': 9.8, 'y': 46, 'z': 0}   left-foot        low-centre
# 19    regular  {'x': 23.6, 'y': 72.8, 'z': 0}   left-foot          low-left
# 20    regular       {'x': 3, 'y': 47, 'z': 0}  right-foot          low-left
# 21  set-piece     {'x': 4.1, 'y': 53, 'z': 0}        head              left
#
#               goalMouthCoordinates                blockCoordinates        xg  \
# 0    {'x': 0, 'y': 48.7, 'z': 3.8}   {'x': 2.5, 'y': 53.6, 'z': 0}  0.117634
# 1     {'x': 0, 'y': 48.6, 'z': 19}  {'x': 14.5, 'y': 64.4, 'z': 0}  0.023829
# 2   {'x': 0, 'y': 52.3, 'z': 25.9}   {'x': 1.2, 'y': 50.2, 'z': 0}  0.090058
# 3   {'x': 0, 'y': 38.8, 'z': 23.6}                             NaN  0.034456
# 4    {'x': 0, 'y': 43.4, 'z': 2.8}                             NaN  0.070249
# 5    {'x': 0, 'y': 45.8, 'z': 4.4}                             NaN  0.169278
# 6      {'x': 0, 'y': 40, 'z': 9.7}                             NaN  0.071526
# 7   {'x': 0, 'y': 46.2, 'z': 52.8}                             NaN  0.263386
# 8     {'x': 0, 'y': 49.8, 'z': 19}   {'x': 5.7, 'y': 51.8, 'z': 0}  0.037330
# 9   {'x': 0, 'y': 52.2, 'z': 20.9}   {'x': 1.2, 'y': 46.4, 'z': 0}  0.049675
# 10   {'x': 0, 'y': 50.7, 'z': 1.9}     {'x': 1.2, 'y': 50, 'z': 0}  0.065993
# 11   {'x': 0, 'y': 48.1, 'z': 3.2}   {'x': 2.2, 'y': 48.2, 'z': 0}  0.029652
# 12    {'x': 0, 'y': 49, 'z': 19.6}   {'x': 0.3, 'y': 50.7, 'z': 0}  0.043100
# 13   {'x': 0, 'y': 49.3, 'z': 1.3}   {'x': 1.1, 'y': 42.8, 'z': 0}  0.063494
# 14  {'x': 0, 'y': 36.3, 'z': 19.4}                             NaN  0.144346
# 15  {'x': 0, 'y': 48.7, 'z': 16.5}     {'x': 2, 'y': 51.6, 'z': 0}  0.070163
# 16  {'x': 0, 'y': 43.2, 'z': 62.5}                             NaN  0.052625
# 17  {'x': 0, 'y': 39.5, 'z': 16.7}                             NaN  0.082718
# 18   {'x': 0, 'y': 48.6, 'z': 2.5}                             NaN  0.296545
# 19    {'x': 0, 'y': 52.1, 'z': 19}  {'x': 18.8, 'y': 67.7, 'z': 0}  0.005263
# 20   {'x': 0, 'y': 52.6, 'z': 1.3}                             NaN  0.265837
# 21     {'x': 0, 'y': 62, 'z': 2.8}     {'x': 1, 'y': 40.4, 'z': 0}  0.262602
#
#     ...       id  time  addedTime  timeSeconds  \
# 0   ...  1252982    90        3.0         5567
# 1   ...  1252981    90        NaN         5380
# 2   ...  1252980    85        NaN         5068
# 3   ...  1252979    77        NaN         4590
# 4   ...  1252978    75        NaN         4461
# 5   ...  1252977    66        NaN         3922
# 6   ...  1252976    62        NaN         3705
# 7   ...  1252975    60        NaN         3559
# 8   ...  1252974    58        NaN         3430
# 9   ...  1252973    55        NaN         3291
# 10  ...  1252972    51        NaN         3027
# 11  ...  1252971    40        NaN         2383
# 12  ...  1252970    39        NaN         2298
# 13  ...  1252969    38        NaN         2227
# 14  ...  1252968    29        NaN         1732
# 15  ...  1252967    24        NaN         1417
# 16  ...  1252966    23        NaN         1323
# 17  ...  1252965    18        NaN         1054
# 18  ...  1252964    10        NaN          590
# 19  ...  1252963     8        NaN          421
# 20  ...  1252962     5        NaN          286
# 21  ...  1252960     3        NaN          152
#
#                                                  draw reversedPeriodTime  \
# 0   {'start': {'x': 57.7, 'y': 6.5}, 'block': {'x'...                  1
# 1   {'start': {'x': 67.8, 'y': 18.2}, 'block': {'x...                  1
# 2   {'start': {'x': 42.9, 'y': 22.4}, 'block': {'x...                  6
# 3   {'start': {'x': 61.8, 'y': 3.1}, 'end': {'x': ...                 14
# 4   {'start': {'x': 49.9, 'y': 15.1}, 'end': {'x':...                 16
# 5   {'start': {'x': 59.2, 'y': 2.8}, 'end': {'x': ...                 25
# 6   {'start': {'x': 49.9, 'y': 14.5}, 'end': {'x':...                 29
# 7   {'start': {'x': 44.1, 'y': 11.1}, 'end': {'x':...                 31
# 8   {'start': {'x': 53.4, 'y': 11.2}, 'block': {'x...                 33
# 9   {'start': {'x': 27.4, 'y': 5.7}, 'block': {'x'...                 36
# 10  {'start': {'x': 50.9, 'y': 15.1}, 'block': {'x...                 40
# 11  {'start': {'x': 31, 'y': 25.8}, 'block': {'x':...                  6
# 12  {'start': {'x': 80, 'y': 10.3}, 'block': {'x':...                  7
# 13  {'start': {'x': 31.8, 'y': 3.1}, 'block': {'x'...                  8
# 14  {'start': {'x': 58.1, 'y': 2.4}, 'end': {'x': ...                 17
# 15  {'start': {'x': 68.4, 'y': 12.7}, 'block': {'x...                 22
# 16  {'start': {'x': 66.6, 'y': 15}, 'end': {'x': 5...                 23
# 17  {'start': {'x': 58.5, 'y': 2.8}, 'end': {'x': ...                 28
# 18  {'start': {'x': 46, 'y': 9.8}, 'end': {'x': 51...                 36
# 19  {'start': {'x': 72.8, 'y': 23.6}, 'block': {'x...                 38
# 20  {'start': {'x': 47, 'y': 3}, 'end': {'x': 47.4...                 41
# 21  {'start': {'x': 53, 'y': 4.1}, 'block': {'x': ...                 43
#
#     reversedPeriodTimeSeconds  periodTimeSeconds  incidentType goalType
# 0                         733                167          shot      NaN
# 1                          20               2680          shot      NaN
# 2                         332               2368          shot      NaN
# 3                         810               1890          shot      NaN
# 4                         939               1761          shot      NaN
# 5                        1478               1222          shot  regular
# 6                        1695               1005          shot      NaN
# 7                        1841                859          shot      NaN
# 8                        1970                730          shot      NaN
# 9                        2109                591          shot      NaN
# 10                       2373                327          shot      NaN
# 11                        317               2383          shot      NaN
# 12                        402               2298          shot      NaN
# 13                        473               2227          shot      NaN
# 14                        968               1732          shot      NaN
# 15                       1283               1417          shot      NaN
# 16                       1377               1323          shot      NaN
# 17                       1646               1054          shot      NaN
# 18                       2110                590          shot  regular
# 19                       2279                421          shot      NaN
# 20                       2414                286          shot  regular
# 21                       2548                152          shot      NaN
#
# [22 rows x 21 columns]

# %%
match_shots.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
team_match_stats = ss.scrape_team_match_stats(8897184)
team_match_stats
# Out:
#                  name home away  compareCode statisticsType valueType  \
# 0     Ball possession  62%  38%            1       positive     event
# 1         Big chances    5    1            1       positive     event
# 2         Total shots   24   15            1       positive     event
# 3    Goalkeeper saves    3    9            2       positive     event
# 4        Corner kicks   10    3            1       positive     event
# ..                ...  ...  ...          ...            ...       ...
# 107     Total tackles    6   11            2       positive     event
# 108     Interceptions    2    4            2       positive     event
# 109        Clearances    3    8            2       positive     event
# 110       Total saves    2    6            2       positive     event
# 111        Goal kicks    5    4            1       positive     event
#
#      homeValue  awayValue  renderType               key period  \
# 0           62         38           2    ballPossession    ALL
# 1            5          1           1  bigChanceCreated    ALL
# 2           24         15           1  totalShotsOnGoal    ALL
# 3            3          9           1   goalkeeperSaves    ALL
# 4           10          3           1       cornerKicks    ALL
# ..         ...        ...         ...               ...    ...
# 107          6         11           1       totalTackle    2ND
# 108          2          4           1   interceptionWon    2ND
# 109          3          8           1    totalClearance    2ND
# 110          2          6           1   goalkeeperSaves    2ND
# 111          5          4           1         goalKicks    2ND
#
#               group  homeTotal  awayTotal
# 0    Match overview        NaN        NaN
# 1    Match overview        NaN        NaN
# 2    Match overview        NaN        NaN
# 3    Match overview        NaN        NaN
# 4    Match overview        NaN        NaN
# ..              ...        ...        ...
# 107       Defending        NaN        NaN
# 108       Defending        NaN        NaN
# 109       Defending        NaN        NaN
# 110     Goalkeeping        NaN        NaN
# 111     Goalkeeping        NaN        NaN
#
# [112 rows x 14 columns]

# %%
player_match_stats = ss.scrape_player_match_stats(11352485)
player_match_stats.columns
# Out:
# Index(['name', 'slug', 'shortName', 'position', 'jerseyNumber', 'height',
#        'userCount', 'gender', 'id', 'country', 'marketValueCurrency',
#        'dateOfBirthTimestamp', 'proposedMarketValueRaw', 'fieldTranslations',
#        'firstName', 'lastName', 'sofascoreId', 'teamId', 'shirtNumber',
#        'jerseyNumber', 'position', 'substitute', 'totalPass', 'accuratePass',
#        'totalLongBalls', 'accurateLongBalls', 'accurateOwnHalfPasses',
#        'totalOwnHalfPasses', 'accurateOppositionHalfPasses',
#        'totalOppositionHalfPasses', 'ballRecovery', 'goodHighClaim',
#        'savedShotsFromInsideTheBox', 'saves', 'minutesPlayed', 'touches',
#        'rating', 'possessionLostCtrl', 'expectedAssists', 'ratingVersions',
#        'totalShots', 'goalsPrevented', 'statisticsType', 'aerialLost',
#        'aerialWon', 'duelLost', 'duelWon', 'totalClearance', 'interceptionWon',
#        'totalTackle', 'wonTackle', 'unsuccessfulTouch', 'wasFouled',
#        'totalCross', 'dispossessed', 'bigChanceCreated', 'outfielderBlock',
#        'fouls', 'keyPass', 'challengeLost', 'totalContest', 'accurateCross',
#        'wonContest', 'shotOffTarget', 'expectedGoals', 'blockedScoringAttempt',
#        'hitWoodwork', 'totalOffside', 'onTargetScoringAttempt',
#        'expectedGoalsOnTarget', 'bigChanceMissed', 'crossNotClaimed',
#        'clearanceOffLine', 'lastManTackle', 'errorLeadToAShot', 'teamName',
#        'captain'],
#       dtype='object')
