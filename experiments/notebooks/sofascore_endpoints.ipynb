# %%
import sys
sys.path.append("../src")

import ScraperFC as sfc  # LEAVE THIS!
ss = sfc.Sofascore()

# %%
match_dicts = ss.get_match_dicts('20/21', "EPL")

# %%
match_dicts[0]
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1178556,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 20/21',
#   'year': '20/21',
#   'editor': False,
#   'id': 29415},
#  'roundInfo': {'round': 19},
#  'customId': 'PY',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 3,
#  'homeTeam': {'name': 'Aston Villa',
#   'slug': 'aston-villa',
#   'shortName': 'Aston Villa',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 847012,
#   'nameCode': 'AVL',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 40,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#670e36',
#    'secondary': '#94bee5',
#    'text': '#94bee5'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'أستون فيلا',
#     'ru': 'Астон Вилла',
#     'hi': 'एस्टन विला',
#     'bn': 'অ্যাস্টন ভিলা'},
#    'shortNameTranslation': {}}},
#  'awayTeam': {'name': 'Everton',
#   'slug': 'everton',
#   'shortName': 'Everton',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 382659,
#   'nameCode': 'EVE',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 48,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#274488',
#    'secondary': '#ffffff',
#    'text': '#ffffff'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'إيفرتون',
#     'ru': 'Эвертон',
#     'hi': 'एवर्टन',
#     'bn': 'এভারটন'},
#    'shortNameTranslation': {}}},
#  'homeScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#  'awayScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#  'coverage': 1,
#  'time': {'injuryTime1': 1,
#   'injuryTime2': 3,
#   'currentPeriodStartTimestamp': 1620932191},
#  'changes': {'changes': ['status.code',
#    'status.description',
#    'status.type',
#    'homeScore.normaltime',
#    'awayScore.normaltime'],
#   'changeTimestamp': 1620932197},
#  'hasGlobalHighlights': False,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 9501660,
#  'slug': 'everton-aston-villa',
#  'startTimestamp': 1620925200,
#  'finalResultOnly': False,
#  'feedLocked': False,
#  'isEditor': False}

# %%
match_dict =  ss.get_match_dict(9501660)
match_dict
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1178556,
#    'hasRounds': True,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'competitionType': 1,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 20/21',
#   'year': '20/21',
#   'editor': False,
#   'id': 29415},
#  'roundInfo': {'round': 19},
#  'customId': 'PY',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 3,
#  'attendance': 0,
#  'venue': {'city': {'name': 'Birmingham'},
#   'venueCoordinates': {'latitude': 52.509126, 'longitude': -1.885035},
#   'hidden': False,
#   'slug': 'villa-park',
#   'name': 'Villa Park',
#   'capacity': 42640,
#   'id': 815,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'فيلا بارك',
#     'hi': 'विला पार्क',
#     'bn': 'ভিলা পার্ক'},
#    'shortNameTranslation': {}},
#   'stadium': {'name': 'Villa Park', 'capacity': 42640}},
#  'referee': {'name': 'Martin Atkinson',
#   'slug': 'atkinson-martin',
#   'yellowCards': 1522,
#   'redCards': 35,
#   'yellowRedCards': 24,
#   'games': 446,
#   'sport': {'id': 1, 'slug': 'football', 'name': 'Football'},
#   'id': 52164,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'أتكينسون، مارتن',
#     'hi': 'एटकिंसन, मार्टिन',
#     'bn': 'অ্যাটকিনসন, মার্টিন'},
#    'shortNameTranslation': {}}},
#  'homeTeam': {'name': 'Aston Villa',
#   'slug': 'aston-villa',
#   'shortName': 'Aston Villa',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 847012,
#   'manager': {'name': 'Unai Emery',
#    'slug': 'unai-emery',
#    'shortName': 'U. Emery',
#    'id': 53062,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'أوني إيمري',
#      'hi': 'उनाई एमरी',
#      'bn': 'উনাই এমেরি'},
#     'shortNameTranslation': {'ar': 'أ. إيمري',
#      'hi': 'यू. एमरी',
#      'bn': 'ইউ. এমেরি'}}},
#   'venue': {'city': {'name': 'Birmingham'},
#    'venueCoordinates': {'latitude': 52.509126, 'longitude': -1.885035},
#    'hidden': False,
#    'slug': 'villa-park',
#    'name': 'Villa Park',
#    'capacity': 42640,
#    'id': 815,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فيلا بارك',
#      'hi': 'विला पार्क',
#      'bn': 'ভিলা পার্ক'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'Villa Park', 'capacity': 42640}},
#   'nameCode': 'AVL',
#   'class': 4,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 40,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Aston Villa',
#   'subTeams': [],
#   'teamColors': {'primary': '#670e36',
#    'secondary': '#94bee5',
#    'text': '#94bee5'},
#   'foundationDateTimestamp': -3024345600,
#   'fieldTranslations': {'nameTranslation': {'ar': 'أستون فيلا',
#     'ru': 'Астон Вилла',
#     'hi': 'एस्टन विला',
#     'bn': 'অ্যাস্টন ভিলা'},
#    'shortNameTranslation': {}},
#   'timeActive': []},
#  'awayTeam': {'name': 'Everton',
#   'slug': 'everton',
#   'shortName': 'Everton',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 382659,
#   'manager': {'name': 'David Moyes',
#    'slug': 'david-moyes',
#    'shortName': 'D. Moyes',
#    'id': 52950,
#    'country': {'alpha2': 'SX',
#     'alpha3': 'SCO',
#     'name': 'Scotland',
#     'slug': 'scotland'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديفيد مويس',
#      'hi': 'डेविड मोयेस',
#      'bn': 'ডেভিড মোয়েস'},
#     'shortNameTranslation': {'ar': 'د. مويس',
#      'hi': 'डी. मोयेस',
#      'bn': 'ডি. মোয়েস'}}},
#   'venue': {'city': {'name': 'Liverpool'},
#    'venueCoordinates': {'latitude': 53.4251, 'longitude': -3.0028},
#    'hidden': True,
#    'slug': 'everton-stadium',
#    'name': 'Hill Dickinson Stadium',
#    'capacity': 52888,
#    'id': 50461,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'stadium': {'name': 'Hill Dickinson Stadium', 'capacity': 52888}},
#   'nameCode': 'EVE',
#   'class': 0,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 48,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Everton',
#   'subTeams': [],
#   'teamColors': {'primary': '#274488',
#    'secondary': '#ffffff',
#    'text': '#ffffff'},
#   'foundationDateTimestamp': -2890166400,
#   'fieldTranslations': {'nameTranslation': {'ar': 'إيفرتون',
#     'ru': 'Эвертон',
#     'hi': 'एवर्टन',
#     'bn': 'এভারটন'},
#    'shortNameTranslation': {}},
#   'timeActive': []},
#  'homeScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#  'awayScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#  'coverage': 1,
#  'time': {'injuryTime1': 1,
#   'injuryTime2': 3,
#   'currentPeriodStartTimestamp': 1620932191},
#  'changes': {'changes': ['status.code',
#    'status.description',
#    'status.type',
#    'homeScore.normaltime',
#    'awayScore.normaltime'],
#   'changeTimestamp': 1620932197},
#  'hasGlobalHighlights': False,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 9501660,
#  'defaultPeriodCount': 2,
#  'defaultPeriodLength': 45,
#  'defaultOvertimeLength': 15,
#  'slug': 'everton-aston-villa',
#  'currentPeriodStartTimestamp': 1620932191,
#  'startTimestamp': 1620925200,
#  'finalResultOnly': False,
#  'feedLocked': False,
#  'seasonStatisticsType': 'overall',
#  'showTotoPromo': True,
#  'isEditor': False}

# %%
# Define the league and season parameters
# Note: Ensure 'EPL' and '23/24' match the expected format for ScraperFC's Sofascore module
LEAGUE = 'EPL'
SEASON = '20/21'

try:
    # 1. Retrieve match dictionaries for the entire season
    # This returns a list of dictionaries, where each dictionary represents a match
    match_dicts = ss.get_match_dicts(year=SEASON, league=LEAGUE)
    
    print(f"Retrieved {len(match_dicts)} match records.")

    # 2. Extract match IDs
    # Iterate through the list and extract the 'id' from each match dictionary
    match_ids = [match['id'] for match in match_dicts if 'id' in match]

    print(f"Extracted {len(match_ids)} match IDs.")
    
    # Optional: Display the first 5 IDs to verify
    print("Sample Match IDs:", match_ids[:5])
    
    # Optional: Check if the specific ID from your example exists in the list
    target_id = 9501660
    if target_id in match_ids:
        print(f"Target match ID {target_id} found in the dataset.")
    else:
        print(f"Target match ID {target_id} NOT found. (Check season/league parameters)")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Retrieved 392 match records.
# Extracted 392 match IDs.
# Sample Match IDs: [9501660, 9507199, 8897157, 8897141, 8897156]
# Target match ID 9501660 found in the dataset.

# %%
match_ids
# Out:
# [9501660,
#  9507199,
#  8897157,
#  8897141,
#  8897156,
#  8897138,
#  8897192,
#  8897184,
#  8897197,
#  8897215,
#  8897160,
#  8897200,
#  8897108,
#  8897174,
#  8897158,
#  8897207,
#  8897198,
#  8897168,
#  8897199,
#  8897152,
#  8897226,
#  8897221,
#  8897220,
#  8897223,
#  8897229,
#  8897228,
#  8897222,
#  8897218,
#  8897224,
#  8897227,
#  8897149,
#  8897186,
#  8897209,
#  8897205,
#  8897213,
#  8897183,
#  8897169,
#  8897115,
#  8897139,
#  8897116,
#  8897109,
#  8897190,
#  8897166,
#  8897131,
#  8897134,
#  8897129,
#  8897212,
#  8897123,
#  8897204,
#  8897112,
#  8897219,
#  8897193,
#  8897143,
#  8897208,
#  8897162,
#  8897110,
#  8897103,
#  8897133,
#  9502921,
#  8897155,
#  8897181,
#  8897146,
#  8897159,
#  8897195,
#  8897171,
#  8897164,
#  8897189,
#  8897148,
#  8897128,
#  8897120,
#  8897154,
#  8897172,
#  8897175,
#  8897180,
#  8897188,
#  8897206,
#  8897170,
#  8897179,
#  8897119,
#  8897127,
#  8897147,
#  8897113,
#  8897211,
#  8897194,
#  8897214,
#  8897187,
#  9437903,
#  8897196,
#  8897126,
#  8897132,
#  8897121,
#  8897072,
#  8897091,
#  8897101,
#  8897087,
#  8897097,
#  8897095,
#  8897090,
#  8897099,
#  8897106,
#  8897082,
#  8897105,
#  8897185,
#  8897079,
#  8897063,
#  8897078,
#  8897069,
#  8897067,
#  8897081,
#  8897064,
#  8897076,
#  8897073,
#  8897083,
#  8897086,
#  8897135,
#  8897075,
#  8897203,
#  9356100,
#  8897167,
#  8897210,
#  8897107,
#  8897182,
#  9326482,
#  9326472,
#  8897178,
#  8897137,
#  8897117,
#  8897136,
#  8897125,
#  8897140,
#  8897102,
#  8897093,
#  8897145,
#  8897100,
#  9326456,
#  8897092,
#  8897098,
#  8897163,
#  8897089,
#  8897153,
#  8897080,
#  8897088,
#  8897114,
#  8897094,
#  8897122,
#  8897077,
#  8897191,
#  8897085,
#  8897074,
#  8897142,
#  8897027,
#  8897039,
#  8897019,
#  8897028,
#  8897034,
#  8897029,
#  8897015,
#  8897024,
#  8897022,
#  8897017,
#  8897036,
#  8897035,
#  8897032,
#  8897026,
#  8897130,
#  8897144,
#  8897150,
#  8897161,
#  8897104,
#  8897173,
#  8897118,
#  8897151,
#  8897201,
#  8897225,
#  8897202,
#  8897111,
#  8897165,
#  8897096,
#  8897124,
#  8897177,
#  8897058,
#  8897052,
#  8897066,
#  8897057,
#  8897048,
#  8897046,
#  8897055,
#  8897070,
#  9258869,
#  8897060,
#  8897041,
#  9282832,
#  8897037,
#  8897044,
#  8897045,
#  8897031,
#  8897025,
#  8897040,
#  8897020,
#  8897042,
#  8897038,
#  8897033,
#  8897054,
#  8897018,
#  8897043,
#  8897021,
#  8897030,
#  8897023,
#  8897050,
#  8897051,
#  8896955,
#  8897008,
#  8896965,
#  8896889,
#  8896935,
#  8896942,
#  8896895,
#  8897013,
#  8897004,
#  8896909,
#  8896917,
#  8896899,
#  8896894,
#  8896902,
#  8896900,
#  8896906,
#  8896903,
#  8896908,
#  8897056,
#  8897047,
#  9258868,
#  8897049,
#  8897053,
#  9277342,
#  8897071,
#  8897068,
#  8897059,
#  8897061,
#  8897062,
#  8897065,
#  8896953,
#  8896954,
#  8896993,
#  8896938,
#  8896987,
#  8897012,
#  8896990,
#  8896958,
#  8896984,
#  8896972,
#  8896964,
#  8896982,
#  8896968,
#  8896959,
#  8896951,
#  8897010,
#  8896969,
#  8896945,
#  8897006,
#  8896912,
#  8896971,
#  8896978,
#  8896920,
#  8896921,
#  8896914,
#  8896936,
#  8896927,
#  8896926,
#  8896931,
#  8896932,
#  8896975,
#  8896979,
#  8896996,
#  8896981,
#  8896864,
#  8896857,
#  8896962,
#  8896995,
#  8896940,
#  8896961,
#  8896966,
#  8897000,
#  8896957,
#  8897014,
#  8896976,
#  8896985,
#  8896977,
#  8897009,
#  8896956,
#  8896980,
#  8897011,
#  8896973,
#  8896941,
#  8896974,
#  8896997,
#  8896952,
#  8896948,
#  8896991,
#  8896989,
#  8896943,
#  8896888,
#  8896865,
#  8896885,
#  8896867,
#  8896859,
#  8897002,
#  8896858,
#  8896863,
#  8896871,
#  8896876,
#  8896866,
#  8896869,
#  8896868,
#  8896847,
#  8896851,
#  8896870,
#  8896883,
#  8896873,
#  8896848,
#  8896994,
#  8896862,
#  8896854,
#  8896850,
#  8896852,
#  8896855,
#  8896849,
#  8896853,
#  8896856,
#  8896999,
#  8896860,
#  8896898,
#  8896897,
#  8896905,
#  8896896,
#  8896910,
#  8896901,
#  8896904,
#  8896884,
#  8897007,
#  8896911,
#  8896916,
#  8897001,
#  8896879,
#  8896907,
#  8896878,
#  8896913,
#  8896881,
#  8896918,
#  8896882,
#  8896890,
#  8896887,
#  8897003,
#  8896880,
#  8896891,
#  8896892,
#  8896875,
#  8896886,
#  8896877,
#  8896874,
#  8896861,
#  8896805,
#  8896804,
#  8896944,
#  8896949,
#  8896963,
#  8896992,
#  8896986,
#  8896998,
#  8896970,
#  8896915,
#  8896928,
#  8896947,
#  8896924,
#  8896922,
#  8897016,
#  8896919,
#  8896950,
#  8896925,
#  8896929,
#  8896933,
#  8896983,
#  8896923,
#  8896946,
#  8896939,
#  8896934,
#  8896960,
#  8896937,
#  8896930,
#  8897005,
#  8896893,
#  8896967,
#  8896988]

# %%
match_shots = ss.scrape_match_shots(9501660)
match_shots
# Out:
#                                                player  isHome shotType  \
# 0   {'name': 'Allan', 'slug': 'allan', 'shortName'...   False     miss
# 1   {'name': 'Dominic Calvert-Lewin', 'slug': 'dom...   False     miss
# 2   {'name': 'Michael Keane', 'slug': 'michael-kea...   False     miss
# 3   {'name': 'Richarlison', 'firstName': '', 'last...   False     miss
# 4   {'name': 'Abdoulaye Doucouré', 'slug': 'abdoul...   False     miss
# 5   {'name': 'Dominic Calvert-Lewin', 'slug': 'dom...   False     save
# 6   {'name': 'Anwar El Ghazi', 'slug': 'anwar-el-g...    True     miss
# 7   {'name': 'Abdoulaye Doucouré', 'slug': 'abdoul...   False     miss
# 8   {'name': 'André Gomes', 'slug': 'andre-gomes',...   False    block
# 9   {'name': 'Ahmed Elmohamady', 'slug': 'ahmed-el...    True     miss
# 10  {'name': 'Anwar El Ghazi', 'slug': 'anwar-el-g...    True     miss
# 11  {'name': 'Jacob Ramsey', 'slug': 'jacob-ramsey...    True    block
# 12  {'name': 'André Gomes', 'slug': 'andre-gomes',...   False     miss
# 13  {'name': 'Mason Holgate', 'slug': 'mason-holga...   False     save
# 14  {'name': 'Bertrand Traoré', 'slug': 'bertrand-...    True     miss
# 15  {'name': 'Anwar El Ghazi', 'slug': 'anwar-el-g...    True     save
# 16  {'name': 'John McGinn', 'slug': 'john-mcginn',...    True    block
# 17  {'name': 'Ben Godfrey', 'slug': 'ben-godfrey',...   False     save
# 18  {'name': 'Abdoulaye Doucouré', 'slug': 'abdoul...   False     miss
# 19  {'name': 'Douglas Luiz', 'firstName': '', 'las...    True     miss
# 20  {'name': 'Richarlison', 'firstName': '', 'last...   False     miss
# 21  {'name': 'Gylfi Sigurðsson', 'slug': 'gylfi-si...   False     save
# 22  {'name': 'Matty Cash', 'slug': 'matty-cash', '...    True    block
# 23  {'name': 'Anwar El Ghazi', 'slug': 'anwar-el-g...    True     miss
# 24  {'name': 'Tyrone Mings', 'firstName': '', 'las...    True     miss
# 25  {'name': 'Dominic Calvert-Lewin', 'slug': 'dom...   False     save
# 26  {'name': 'Bertrand Traoré', 'slug': 'bertrand-...    True     save
# 27  {'name': 'Bertrand Traoré', 'slug': 'bertrand-...    True    block
#
#              situation               playerCoordinates    bodyPart  \
# 0   throw-in-set-piece    {'x': 13, 'y': 45.4, 'z': 0}  right-foot
# 1             assisted  {'x': 10.9, 'y': 54.5, 'z': 0}        head
# 2            set-piece     {'x': 9, 'y': 66.3, 'z': 0}        head
# 3             assisted       {'x': 4, 'y': 46, 'z': 0}        head
# 4              regular  {'x': 12.8, 'y': 54.2, 'z': 0}  right-foot
# 5             assisted   {'x': 5.5, 'y': 59.4, 'z': 0}        head
# 6             assisted  {'x': 17.6, 'y': 63.9, 'z': 0}   left-foot
# 7             assisted  {'x': 10.3, 'y': 42.4, 'z': 0}  right-foot
# 8             assisted  {'x': 18.3, 'y': 50.4, 'z': 0}  right-foot
# 9               corner     {'x': 9, 'y': 43.9, 'z': 0}        head
# 10            assisted  {'x': 12.6, 'y': 45.4, 'z': 0}   left-foot
# 11            assisted  {'x': 13.9, 'y': 34.9, 'z': 0}  right-foot
# 12            assisted    {'x': 17, 'y': 50.7, 'z': 0}   left-foot
# 13           set-piece   {'x': 5.7, 'y': 30.7, 'z': 0}        head
# 14              corner  {'x': 20.8, 'y': 36.9, 'z': 0}   left-foot
# 15           free-kick    {'x': 24, 'y': 27.9, 'z': 0}  right-foot
# 16              corner     {'x': 8, 'y': 43.9, 'z': 0}   left-foot
# 17           set-piece   {'x': 2.1, 'y': 62.9, 'z': 0}  right-foot
# 18            assisted  {'x': 17.1, 'y': 60.4, 'z': 0}  right-foot
# 19              corner    {'x': 20.2, 'y': 62, 'z': 0}  right-foot
# 20            assisted    {'x': 18.5, 'y': 53, 'z': 0}   left-foot
# 21           free-kick  {'x': 27.6, 'y': 37.3, 'z': 0}  right-foot
# 22            assisted  {'x': 14.7, 'y': 72.8, 'z': 0}  right-foot
# 23            assisted  {'x': 27.5, 'y': 49.9, 'z': 0}  right-foot
# 24              corner   {'x': 8.3, 'y': 54.9, 'z': 0}        head
# 25            assisted   {'x': 9.3, 'y': 44.8, 'z': 0}        head
# 26            assisted  {'x': 20.1, 'y': 55.8, 'z': 0}   left-foot
# 27              corner    {'x': 14.6, 'y': 24, 'z': 0}   left-foot
#
#    goalMouthLocation            goalMouthCoordinates       id  time  \
# 0               high  {'x': 0, 'y': 44.9, 'z': 79.2}  1003296    90
# 1         high-right  {'x': 0, 'y': 34.1, 'z': 52.8}  1003295    90
# 2              right  {'x': 0, 'y': 31.1, 'z': 15.3}  1003294    89
# 3          high-left  {'x': 0, 'y': 56.3, 'z': 72.2}  1003293    87
# 4               left    {'x': 0, 'y': 63.5, 'z': 25}  1003292    87
# 5          low-right  {'x': 0, 'y': 47.3, 'z': 10.8}  1003291    87
# 6          high-left  {'x': 0, 'y': 63.5, 'z': 83.3}  1003290    79
# 7               high  {'x': 0, 'y': 52.3, 'z': 91.7}  1003289    78
# 8         low-centre      {'x': 0, 'y': 50, 'z': 19}  1003288    78
# 9               high  {'x': 0, 'y': 55.6, 'z': 76.4}  1003287    74
# 10              left  {'x': 0, 'y': 66.1, 'z': 19.4}  1003286    73
# 11        low-centre      {'x': 0, 'y': 51, 'z': 19}  1003285    70
# 12         high-left  {'x': 0, 'y': 59.3, 'z': 77.8}  1003284    69
# 13       high-centre  {'x': 0, 'y': 51.2, 'z': 21.5}  1003283    63
# 14              high  {'x': 0, 'y': 53.1, 'z': 87.5}  1003282    61
# 15          low-left    {'x': 0, 'y': 52.3, 'z': 19}  1003281    61
# 16        low-centre    {'x': 0, 'y': 48.4, 'z': 19}  1003280    59
# 17        high-right  {'x': 0, 'y': 46.1, 'z': 20.9}  1003279    52
# 18              left  {'x': 0, 'y': 67.7, 'z': 12.5}  1003278    46
# 19              high  {'x': 0, 'y': 46.4, 'z': 80.6}  1003277    42
# 20              left   {'x': 0, 'y': 62.2, 'z': 9.7}  1003276    35
# 21         high-left  {'x': 0, 'y': 52.3, 'z': 20.3}  1003275    30
# 22          low-left  {'x': 0, 'y': 53.4, 'z': 19.4}  1003274    24
# 23        high-right  {'x': 0, 'y': 39.8, 'z': 73.6}  1003273    21
# 24       close-right  {'x': 0, 'y': 41.3, 'z': 15.3}  1003272    17
# 25        low-centre  {'x': 0, 'y': 49.2, 'z': 15.2}  1003271    15
# 26        low-centre   {'x': 0, 'y': 50.6, 'z': 1.3}  1003270    11
# 27        low-centre    {'x': 0, 'y': 50.5, 'z': 19}  1003269     2
#
#     addedTime  timeSeconds                                               draw  \
# 0         6.0         5728  {'start': {'x': 45.4, 'y': 13}, 'end': {'x': 5...
# 1         1.0         5439  {'start': {'x': 54.5, 'y': 10.9}, 'end': {'x':...
# 2         NaN         5314  {'start': {'x': 66.3, 'y': 9}, 'block': {'x': ...
# 3         NaN         5205  {'start': {'x': 46, 'y': 4}, 'end': {'x': 43.7...
# 4         NaN         5204  {'start': {'x': 54.2, 'y': 12.8}, 'block': {'x...
# 5         NaN         5203  {'start': {'x': 59.4, 'y': 5.5}, 'block': {'x'...
# 6         NaN         4709  {'start': {'x': 63.9, 'y': 17.6}, 'end': {'x':...
# 7         NaN         4634  {'start': {'x': 42.4, 'y': 10.3}, 'end': {'x':...
# 8         NaN         4624  {'start': {'x': 50.4, 'y': 18.3}, 'block': {'x...
# 9         NaN         4414  {'start': {'x': 43.9, 'y': 9}, 'end': {'x': 44...
# 10        NaN         4379  {'start': {'x': 45.4, 'y': 12.6}, 'block': {'x...
# 11        NaN         4158  {'start': {'x': 34.9, 'y': 13.9}, 'block': {'x...
# 12        NaN         4088  {'start': {'x': 50.7, 'y': 17}, 'end': {'x': 4...
# 13        NaN         3775  {'start': {'x': 30.7, 'y': 5.7}, 'block': {'x'...
# 14        NaN         3652  {'start': {'x': 36.9, 'y': 20.8}, 'end': {'x':...
# 15        NaN         3620  {'start': {'x': 27.9, 'y': 24}, 'block': {'x':...
# 16        NaN         3485  {'start': {'x': 43.9, 'y': 8}, 'block': {'x': ...
# 17        NaN         3069  {'start': {'x': 62.9, 'y': 2.1}, 'block': {'x'...
# 18        NaN         2751  {'start': {'x': 60.4, 'y': 17.1}, 'block': {'x...
# 19        NaN         2474  {'start': {'x': 62, 'y': 20.2}, 'end': {'x': 5...
# 20        NaN         2060  {'start': {'x': 53, 'y': 18.5}, 'end': {'x': 3...
# 21        NaN         1788  {'start': {'x': 37.3, 'y': 27.6}, 'block': {'x...
# 22        NaN         1413  {'start': {'x': 72.8, 'y': 14.7}, 'block': {'x...
# 23        NaN         1203  {'start': {'x': 49.9, 'y': 27.5}, 'end': {'x':...
# 24        NaN         1012  {'start': {'x': 54.9, 'y': 8.3}, 'end': {'x': ...
# 25        NaN          874  {'start': {'x': 44.8, 'y': 9.3}, 'block': {'x'...
# 26        NaN          636  {'start': {'x': 55.8, 'y': 20.1}, 'block': {'x...
# 27        NaN           81  {'start': {'x': 24, 'y': 14.6}, 'block': {'x':...
#
#     reversedPeriodTime  reversedPeriodTimeSeconds  periodTimeSeconds  \
# 0                    1                        572                328
# 1                    1                        861                 39
# 2                    2                         86               2614
# 3                    4                        195               2505
# 4                    4                        196               2504
# 5                    4                        197               2503
# 6                   12                        691               2009
# 7                   13                        766               1934
# 8                   13                        776               1924
# 9                   17                        986               1714
# 10                  18                       1021               1679
# 11                  21                       1242               1458
# 12                  22                       1312               1388
# 13                  28                       1625               1075
# 14                  30                       1748                952
# 15                  30                       1780                920
# 16                  32                       1915                785
# 17                  39                       2331                369
# 18                  45                       2649                 51
# 19                   4                        226               2474
# 20                  11                        640               2060
# 21                  16                        912               1788
# 22                  22                       1287               1413
# 23                  25                       1497               1203
# 24                  29                       1688               1012
# 25                  31                       1826                874
# 26                  35                       2064                636
# 27                  44                       2619                 81
#
#    incidentType                blockCoordinates
# 0          shot                             NaN
# 1          shot                             NaN
# 2          shot   {'x': 2.4, 'y': 70.4, 'z': 0}
# 3          shot                             NaN
# 4          shot   {'x': 4.2, 'y': 45.3, 'z': 0}
# 5          shot   {'x': 1.1, 'y': 53.4, 'z': 0}
# 6          shot                             NaN
# 7          shot                             NaN
# 8          shot   {'x': 7.7, 'y': 50.2, 'z': 0}
# 9          shot                             NaN
# 10         shot   {'x': 3.6, 'y': 39.2, 'z': 0}
# 11         shot  {'x': 11.1, 'y': 37.7, 'z': 0}
# 12         shot                             NaN
# 13         shot   {'x': 1.4, 'y': 44.8, 'z': 0}
# 14         shot                             NaN
# 15         shot   {'x': 1.1, 'y': 50.7, 'z': 0}
# 16         shot   {'x': 4.5, 'y': 47.3, 'z': 0}
# 17         shot   {'x': 0.7, 'y': 54.2, 'z': 0}
# 18         shot   {'x': 8.5, 'y': 47.8, 'z': 0}
# 19         shot                             NaN
# 20         shot                             NaN
# 21         shot     {'x': 1, 'y': 51.3, 'z': 0}
# 22         shot  {'x': 13.7, 'y': 70.9, 'z': 0}
# 23         shot                             NaN
# 24         shot                             NaN
# 25         shot   {'x': 1.5, 'y': 48.4, 'z': 0}
# 26         shot   {'x': 1.9, 'y': 49.6, 'z': 0}
# 27         shot    {'x': 11, 'y': 30.3, 'z': 0}

# %%
team_match_stats = ss.scrape_team_match_stats(9501660)
team_match_stats
# Out:
#                  name home away  compareCode statisticsType valueType  \
# 0     Ball possession  58%  42%            1       positive     event
# 1         Big chances    1    0            1       positive     event
# 2         Total shots   13   15            2       positive     event
# 3    Goalkeeper saves    5    2            1       positive     event
# 4        Corner kicks    9    1            1       positive     event
# ..                ...  ...  ...          ...            ...       ...
# 104     Total tackles    4    4            3       positive     event
# 105     Interceptions    3    3            3       positive     event
# 106        Clearances   10    8            1       positive     event
# 107       Total saves    3    1            1       positive     event
# 108        Goal kicks    6    6            3       positive     event
#
#      homeValue  awayValue  renderType               key period  \
# 0           58         42           2    ballPossession    ALL
# 1            1          0           1  bigChanceCreated    ALL
# 2           13         15           1  totalShotsOnGoal    ALL
# 3            5          2           1   goalkeeperSaves    ALL
# 4            9          1           1       cornerKicks    ALL
# ..         ...        ...         ...               ...    ...
# 104          4          4           1       totalTackle    2ND
# 105          3          3           1   interceptionWon    2ND
# 106         10          8           1    totalClearance    2ND
# 107          3          1           1   goalkeeperSaves    2ND
# 108          6          6           1         goalKicks    2ND
#
#               group  homeTotal  awayTotal
# 0    Match overview        NaN        NaN
# 1    Match overview        NaN        NaN
# 2    Match overview        NaN        NaN
# 3    Match overview        NaN        NaN
# 4    Match overview        NaN        NaN
# ..              ...        ...        ...
# 104       Defending        NaN        NaN
# 105       Defending        NaN        NaN
# 106       Defending        NaN        NaN
# 107     Goalkeeping        NaN        NaN
# 108     Goalkeeping        NaN        NaN
#
# [109 rows x 14 columns]

# %%
player_match_stats = ss.scrape_player_match_stats(9501660)
player_match_stats.columns
# Out:
# Index(['name', 'slug', 'shortName', 'position', 'jerseyNumber', 'height',
#        'userCount', 'gender', 'sofascoreId', 'id', 'country',
#        'marketValueCurrency', 'dateOfBirthTimestamp', 'proposedMarketValueRaw',
#        'fieldTranslations', 'firstName', 'lastName', 'teamId', 'shirtNumber',
#        'jerseyNumber', 'position', 'substitute', 'totalPass', 'accuratePass',
#        'totalLongBalls', 'accurateLongBalls', 'accurateOwnHalfPasses',
#        'totalOwnHalfPasses', 'accurateOppositionHalfPasses',
#        'totalOppositionHalfPasses', 'aerialWon', 'duelWon', 'ballRecovery',
#        'wasFouled', 'goodHighClaim', 'savedShotsFromInsideTheBox', 'saves',
#        'totalKeeperSweeper', 'accurateKeeperSweeper', 'minutesPlayed',
#        'touches', 'rating', 'possessionLostCtrl', 'totalShots',
#        'statisticsType', 'totalCross', 'aerialLost', 'duelLost',
#        'dispossessed', 'totalContest', 'wonContest', 'blockedScoringAttempt',
#        'totalClearance', 'interceptionWon', 'fouls', 'bigChanceMissed',
#        'shotOffTarget', 'totalTackle', 'wonTackle', 'accurateCross',
#        'challengeLost', 'keyPass', 'unsuccessfulTouch', 'bigChanceCreated',
#        'onTargetScoringAttempt', 'outfielderBlock', 'totalOffside', 'teamName',
#        'captain'],
#       dtype='object')
