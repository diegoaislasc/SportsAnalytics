# %%
import sys
sys.path.append("../src")

import ScraperFC as sfc  # LEAVE THIS!
ss = sfc.Sofascore()

# %%
match_dicts = ss.get_match_dicts('23/24', "EPL")

# %%
match_dicts[0]
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1179726,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 23/24',
#   'year': '23/24',
#   'editor': False,
#   'id': 52186},
#  'roundInfo': {'round': 36},
#  'customId': 'Tsab',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 3,
#  'homeTeam': {'name': 'Brentford',
#   'slug': 'brentford',
#   'shortName': 'Brentford',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 290729,
#   'nameCode': 'BRE',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 50,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#ffffff',
#    'secondary': '#ff0000',
#    'text': '#ff0000'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'برينتفورد',
#     'ru': 'Брентфорд',
#     'hi': 'ब्रेंटफोर्ड',
#     'bn': 'ব্রেন্টফোর্ড'},
#    'shortNameTranslation': {}}},
#  'awayTeam': {'name': 'Fulham',
#   'slug': 'fulham',
#   'shortName': 'Fulham',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 326897,
#   'nameCode': 'FUL',
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 43,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'subTeams': [],
#   'teamColors': {'primary': '#ffffff',
#    'secondary': '#000000',
#    'text': '#000000'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'فولهام',
#     'ru': 'Фулхэм',
#     'hi': 'फुलहम',
#     'bn': 'ফুলহাম'},
#    'shortNameTranslation': {}}},
#  'homeScore': {'current': 0,
#   'display': 0,
#   'period1': 0,
#   'period2': 0,
#   'normaltime': 0},
#  'awayScore': {'current': 0,
#   'display': 0,
#   'period1': 0,
#   'period2': 0,
#   'normaltime': 0},
#  'time': {'injuryTime1': 3,
#   'injuryTime2': 6,
#   'currentPeriodStartTimestamp': 1714835266},
#  'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#   'changeTimestamp': 1714838359},
#  'hasGlobalHighlights': True,
#  'hasXg': True,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 11352485,
#  'slug': 'brentford-fulham',
#  'startTimestamp': 1714831200,
#  'finalResultOnly': False,
#  'feedLocked': True,
#  'isEditor': False}

# %%
match_dict =  ss.get_match_dict(11352660)
match_dict
# Out:
# {'eventState': {},
#  'tournament': {'name': 'Premier League',
#   'slug': 'premier-league',
#   'category': {'name': 'England',
#    'slug': 'england',
#    'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#    'id': 1,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'flag': 'england',
#    'alpha2': 'EN',
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#      'hi': 'इंग्लैंड',
#      'bn': 'ইংল্যান্ড'},
#     'shortNameTranslation': {}}},
#   'uniqueTournament': {'name': 'Premier League',
#    'slug': 'premier-league',
#    'primaryColorHex': '#3c1c5a',
#    'secondaryColorHex': '#f80158',
#    'category': {'name': 'England',
#     'slug': 'england',
#     'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#     'id': 1,
#     'country': {'alpha2': 'EN',
#      'alpha3': 'ENG',
#      'name': 'England',
#      'slug': 'england'},
#     'flag': 'england',
#     'alpha2': 'EN',
#     'fieldTranslations': {'nameTranslation': {'ar': 'إنجلترا',
#       'hi': 'इंग्लैंड',
#       'bn': 'ইংল্যান্ড'},
#      'shortNameTranslation': {}}},
#    'userCount': 1178989,
#    'hasRounds': True,
#    'hasPerformanceGraphFeature': True,
#    'id': 17,
#    'country': {},
#    'hasEventPlayerStatistics': True,
#    'displayInverseHomeAwayTeams': False,
#    'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#      'hi': 'प्रिमियर लीग',
#      'bn': 'প্রিমিয়ার লীগ'},
#     'shortNameTranslation': {}}},
#   'priority': 699,
#   'isGroup': False,
#   'competitionType': 1,
#   'isLive': False,
#   'id': 1,
#   'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الإنجليزي الممتاز',
#     'hi': 'प्रिमियर लीग',
#     'bn': 'প্রিমিয়ার লীগ'},
#    'shortNameTranslation': {}}},
#  'season': {'name': 'Premier League 23/24',
#   'year': '23/24',
#   'editor': False,
#   'id': 52186},
#  'roundInfo': {'round': 9},
#  'customId': 'gsab',
#  'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#  'winnerCode': 1,
#  'attendance': 17029,
#  'venue': {'city': {'name': 'London'},
#   'venueCoordinates': {'latitude': 51.490713, 'longitude': -0.28898},
#   'hidden': False,
#   'slug': 'brentford-community-stadium',
#   'name': 'Brentford Community Stadium',
#   'capacity': 17250,
#   'id': 29716,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'ملعب برينتفورد المجتمعي',
#     'hi': 'ब्रेंटफोर्ड कम्युनिटी स्टेडियम',
#     'bn': 'ব্রেন্টফোর্ড কমিউনিটি স্টেডিয়াম'},
#    'shortNameTranslation': {}},
#   'stadium': {'name': 'Brentford Community Stadium', 'capacity': 17250}},
#  'referee': {'name': 'Josh Smith',
#   'slug': 'smith-josh',
#   'yellowCards': 680,
#   'redCards': 15,
#   'yellowRedCards': 10,
#   'games': 178,
#   'sport': {'id': 1, 'slug': 'football', 'name': 'Football'},
#   'id': 787286,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'سميث، جوش',
#     'hi': 'स्मिथ, जोश',
#     'bn': 'স্মিথ, জোশ'},
#    'shortNameTranslation': {}}},
#  'homeTeam': {'name': 'Brentford',
#   'slug': 'brentford',
#   'shortName': 'Brentford',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 288272,
#   'manager': {'name': 'Keith Andrews',
#    'slug': 'keith-andrews',
#    'shortName': 'K. Andrews',
#    'id': 811460,
#    'country': {'alpha2': 'IE',
#     'alpha3': 'IRL',
#     'name': 'Ireland',
#     'slug': 'ireland'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'كيث أندروز'},
#     'shortNameTranslation': {'ar': 'ك. أندروز'}}},
#   'venue': {'city': {'name': 'London'},
#    'venueCoordinates': {'latitude': 51.490713, 'longitude': -0.28898},
#    'hidden': False,
#    'slug': 'brentford-community-stadium',
#    'name': 'Brentford Community Stadium',
#    'capacity': 17250,
#    'id': 29716,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ملعب برينتفورد المجتمعي',
#      'hi': 'ब्रेंटफोर्ड कम्युनिटी स्टेडियम',
#      'bn': 'ব্রেন্টফোর্ড কমিউনিটি স্টেডিয়াম'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'Brentford Community Stadium', 'capacity': 17250}},
#   'nameCode': 'BRE',
#   'class': 0,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 50,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Brentford',
#   'subTeams': [],
#   'teamColors': {'primary': '#ffffff',
#    'secondary': '#ff0000',
#    'text': '#ff0000'},
#   'foundationDateTimestamp': -2531779200,
#   'fieldTranslations': {'nameTranslation': {'ar': 'برينتفورد',
#     'ru': 'Брентфорд',
#     'hi': 'ब्रेंटफोर्ड',
#     'bn': 'ব্রেন্টফোর্ড'},
#    'shortNameTranslation': {}},
#   'timeActive': []},
#  'awayTeam': {'name': 'Burnley',
#   'slug': 'burnley',
#   'shortName': 'Burnley',
#   'gender': 'M',
#   'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#   'userCount': 151742,
#   'manager': {'name': 'Scott Parker',
#    'slug': 'scott-parker',
#    'shortName': 'S. Parker',
#    'id': 791276,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'سكوت باركر'},
#     'shortNameTranslation': {'ar': 'س. باركر'}}},
#   'venue': {'city': {'name': 'Burnley'},
#    'venueCoordinates': {'latitude': 53.789355, 'longitude': -2.229895},
#    'hidden': False,
#    'slug': 'turf-moor',
#    'name': 'Turf Moor',
#    'capacity': 21944,
#    'id': 806,
#    'country': {'alpha2': 'EN',
#     'alpha3': 'ENG',
#     'name': 'England',
#     'slug': 'england'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'تيرف مور',
#      'hi': 'टर्फ मूर',
#      'bn': 'টার্ফ মুর'},
#     'shortNameTranslation': {}},
#    'stadium': {'name': 'Turf Moor', 'capacity': 21944}},
#   'nameCode': 'BUR',
#   'class': 0,
#   'disabled': False,
#   'national': False,
#   'type': 0,
#   'id': 6,
#   'country': {'alpha2': 'EN',
#    'alpha3': 'ENG',
#    'name': 'England',
#    'slug': 'england'},
#   'fullName': 'Burnley',
#   'subTeams': [],
#   'teamColors': {'primary': '#81204c',
#    'secondary': '#8fd2f4',
#    'text': '#8fd2f4'},
#   'foundationDateTimestamp': -2776982400,
#   'fieldTranslations': {'nameTranslation': {'ar': 'بيرنلي',
#     'ru': 'Бернли',
#     'hi': 'बर्नली',
#     'bn': 'বার্নলি'},
#    'shortNameTranslation': {}},
#   'timeActive': []},
#  'homeScore': {'current': 3,
#   'display': 3,
#   'period1': 1,
#   'period2': 2,
#   'normaltime': 3},
#  'awayScore': {'current': 0,
#   'display': 0,
#   'period1': 0,
#   'period2': 0,
#   'normaltime': 0},
#  'time': {'injuryTime1': 4,
#   'injuryTime2': 7,
#   'currentPeriodStartTimestamp': 1697903905},
#  'changes': {'changes': ['status.code',
#    'status.description',
#    'status.type',
#    'homeScore.period2',
#    'homeScore.normaltime',
#    'awayScore.period2',
#    'awayScore.normaltime',
#    'time.currentPeriodStart'],
#   'changeTimestamp': 1697903910},
#  'hasGlobalHighlights': False,
#  'hasXg': True,
#  'hasEventPlayerStatistics': True,
#  'hasEventPlayerHeatMap': True,
#  'detailId': 1,
#  'crowdsourcingDataDisplayEnabled': False,
#  'id': 11352660,
#  'awayRedCards': 1,
#  'defaultPeriodCount': 2,
#  'defaultPeriodLength': 45,
#  'defaultOvertimeLength': 15,
#  'slug': 'brentford-burnley',
#  'currentPeriodStartTimestamp': 1697903905,
#  'startTimestamp': 1697896800,
#  'finalResultOnly': False,
#  'feedLocked': True,
#  'seasonStatisticsType': 'overall',
#  'showTotoPromo': True,
#  'isEditor': False}

# %%
# Define the league and season parameters
# Note: Ensure 'EPL' and '23/24' match the expected format for ScraperFC's Sofascore module
LEAGUE = 'EPL'
SEASON = '23/24'

try:
    # 1. Retrieve match dictionaries for the entire season
    # This returns a list of dictionaries, where each dictionary represents a match
    match_dicts = ss.get_match_dicts(year=SEASON, league=LEAGUE)
    
    print(f"Retrieved {len(match_dicts)} match records.")

    # 2. Extract match IDs
    # Iterate through the list and extract the 'id' from each match dictionary
    match_ids = [match['id'] for match in match_dicts if 'id' in match]

    print(f"Extracted {len(match_ids)} match IDs.")
    
    # Optional: Display the first 5 IDs to verify
    print("Sample Match IDs:", match_ids[:5])
    
    # Optional: Check if the specific ID from your example exists in the list
    target_id = 11352660
    if target_id in match_ids:
        print(f"Target match ID {target_id} found in the dataset.")
    else:
        print(f"Target match ID {target_id} NOT found. (Check season/league parameters)")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Retrieved 380 match records.
# Extracted 380 match IDs.
# Sample Match IDs: [11352485, 11352491, 11352507, 11352488, 11352494]
# Target match ID 11352660 found in the dataset.

# %%
match_ids
# Out:
# [11352485,
#  11352491,
#  11352507,
#  11352488,
#  11352494,
#  11352500,
#  12226495,
#  11352529,
#  11352519,
#  11352527,
#  11352516,
#  11352513,
#  11352536,
#  11352542,
#  11352539,
#  11352532,
#  11352523,
#  12240634,
#  12240570,
#  12240571,
#  11352555,
#  11352568,
#  11352562,
#  11352549,
#  11352574,
#  11352558,
#  11352546,
#  11352565,
#  11352552,
#  11352571,
#  11352403,
#  11352390,
#  11352401,
#  11352441,
#  11352434,
#  11352448,
#  11352429,
#  11352425,
#  11352420,
#  11352432,
#  12190322,
#  12190332,
#  12190340,
#  12190336,
#  12190339,
#  12190341,
#  11352476,
#  11352479,
#  11352460,
#  11352467,
#  11352463,
#  11352457,
#  11352454,
#  11352451,
#  11352472,
#  11352470,
#  12226774,
#  11352503,
#  11352482,
#  11352510,
#  11352614,
#  11352617,
#  11352619,
#  11352333,
#  11352343,
#  11352319,
#  11352330,
#  11352336,
#  11352325,
#  11352322,
#  11352352,
#  11352347,
#  11352340,
#  11352362,
#  11352371,
#  11352364,
#  11352384,
#  11352355,
#  11352368,
#  11352359,
#  11352374,
#  11352378,
#  11352381,
#  11352410,
#  11352394,
#  11352413,
#  11352397,
#  11352406,
#  11352387,
#  11352416,
#  11352553,
#  11352564,
#  11352530,
#  11352556,
#  11352545,
#  11352533,
#  11352548,
#  11352560,
#  11352591,
#  11352567,
#  11352585,
#  11352595,
#  11352572,
#  11352575,
#  11352579,
#  11352593,
#  11352588,
#  11352581,
#  11977248,
#  11352606,
#  11352599,
#  11352604,
#  11352609,
#  11352620,
#  11352622,
#  11352623,
#  11352612,
#  11352624,
#  11352616,
#  11352613,
#  11352419,
#  11352446,
#  11352439,
#  11352423,
#  11352435,
#  11352443,
#  11352412,
#  11352415,
#  11352450,
#  11352478,
#  11352462,
#  11352474,
#  11352486,
#  11352453,
#  11352469,
#  11352481,
#  11352465,
#  11352458,
#  11971437,
#  11352512,
#  11352509,
#  11352502,
#  11352499,
#  11352518,
#  11352490,
#  11352493,
#  11352525,
#  11352521,
#  11352540,
#  11352537,
#  11352331,
#  11352324,
#  11352328,
#  11352311,
#  11352313,
#  11352334,
#  11352308,
#  11352315,
#  11352348,
#  11352342,
#  11352344,
#  11352361,
#  11352338,
#  11352351,
#  11352369,
#  11352365,
#  11352354,
#  11896302,
#  11352395,
#  11352386,
#  11352383,
#  11352402,
#  11352409,
#  11352372,
#  11352392,
#  11352398,
#  11352376,
#  11352380,
#  11352431,
#  11352427,
#  11352511,
#  11352535,
#  11352528,
#  11352517,
#  11352522,
#  11352531,
#  11352520,
#  11352538,
#  11352566,
#  11352569,
#  11352541,
#  11352554,
#  11352563,
#  11352547,
#  11352557,
#  11352559,
#  11777280,
#  11777281,
#  11352582,
#  11352576,
#  11352592,
#  11352573,
#  11352583,
#  11352586,
#  11352587,
#  11352577,
#  11352580,
#  11352589,
#  11352318,
#  11352321,
#  11352440,
#  11352430,
#  11352442,
#  11352426,
#  11352421,
#  11352433,
#  11352417,
#  11352445,
#  11352424,
#  11777279,
#  11352455,
#  11352471,
#  11352477,
#  11352452,
#  11352468,
#  11352449,
#  11352461,
#  11352459,
#  11352464,
#  11352473,
#  11352505,
#  11352501,
#  11352492,
#  11352498,
#  11352489,
#  11352508,
#  11352487,
#  11352483,
#  11352496,
#  11352514,
#  11352349,
#  11352335,
#  11352353,
#  11352341,
#  11352350,
#  11352329,
#  11352345,
#  11352326,
#  11352339,
#  11352332,
#  11352373,
#  11352382,
#  11352370,
#  11352379,
#  11352360,
#  11352375,
#  11352356,
#  11352385,
#  11352363,
#  11352366,
#  11352396,
#  11352393,
#  11352391,
#  11352411,
#  11352408,
#  11352388,
#  11352414,
#  11352400,
#  11352404,
#  11352405,
#  11352662,
#  11352665,
#  11352657,
#  11352660,
#  11352664,
#  11352663,
#  11352661,
#  11352666,
#  11352658,
#  11352667,
#  11352673,
#  11352672,
#  11352668,
#  11352669,
#  11352677,
#  11352676,
#  11352670,
#  11352671,
#  11352674,
#  11352675,
#  11352307,
#  11352305,
#  11352320,
#  11352304,
#  11352306,
#  11352312,
#  11352314,
#  11352317,
#  11352310,
#  11352323,
#  11352632,
#  11352635,
#  11352628,
#  11352630,
#  11352629,
#  11352631,
#  11352627,
#  11352633,
#  11352636,
#  11352638,
#  11352639,
#  11352645,
#  11352642,
#  11352637,
#  11352641,
#  11352646,
#  11352644,
#  11352643,
#  11352640,
#  11626262,
#  11352653,
#  11352652,
#  11352651,
#  11352649,
#  11352654,
#  11352650,
#  11352656,
#  11352655,
#  11352648,
#  11352647,
#  11352437,
#  11352456,
#  11352495,
#  11352447,
#  11352504,
#  11352466,
#  11352475,
#  11352524,
#  11352515,
#  11352590,
#  11352597,
#  11352543,
#  11352561,
#  11352570,
#  11352594,
#  11352551,
#  11352578,
#  11352584,
#  11352534,
#  11352626,
#  11352608,
#  11352602,
#  11352621,
#  11352611,
#  11352625,
#  11352615,
#  11352600,
#  11352605,
#  11352618,
#  11352634,
#  11352303,
#  11352251,
#  11352254,
#  11352252,
#  11352253,
#  11352250,
#  11352255,
#  11352309,
#  11352316,
#  11352327,
#  11352399,
#  11352358,
#  11352428,
#  11352367,
#  11352407,
#  11352389,
#  11352337,
#  11352418,
#  11352346,
#  11352484]

# %%
match_shots = ss.scrape_match_shots(11352660)
match_shots
# Out:
#                                                player  isHome shotType  \
# 0   {'name': 'Yehor Yarmolyuk', 'firstName': '', '...    True     miss
# 1   {'name': 'Saman Ghoddos', 'firstName': '', 'la...    True     miss
# 2   {'name': 'Saman Ghoddos', 'firstName': '', 'la...    True     goal
# 3   {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True     save
# 4   {'name': 'Luca Koleosho', 'firstName': 'Luca K...   False     miss
# 5   {'name': 'Neal Maupay', 'slug': 'neal-maupay',...    True    block
# 6   {'name': 'Frank Onyeka', 'firstName': '', 'las...    True    block
# 7   {'name': 'Mathias Jensen', 'slug': 'mathias-je...    True     miss
# 8   {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True     goal
# 9   {'name': 'Zeki Amdouni', 'firstName': '', 'las...   False     miss
# 10  {'name': 'Luca Koleosho', 'firstName': 'Luca K...   False    block
# 11  {'name': 'Zeki Amdouni', 'firstName': '', 'las...   False     save
# 12  {'name': 'Neal Maupay', 'slug': 'neal-maupay',...    True     save
# 13  {'name': 'Yoane Wissa', 'slug': 'yoane-wissa',...    True     save
# 14  {'name': 'Christian Nørgaard', 'slug': 'christ...    True     miss
# 15  {'name': 'Wilson Odobert', 'slug': 'wilson-odo...   False     miss
# 16  {'name': 'Kristoffer Ajer', 'slug': 'kristoffe...    True     miss
# 17  {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True     save
# 18  {'name': 'Christian Nørgaard', 'slug': 'christ...    True     miss
# 19  {'name': 'Neal Maupay', 'slug': 'neal-maupay',...    True    block
# 20  {'name': 'Yoane Wissa', 'slug': 'yoane-wissa',...    True     goal
# 21  {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True     save
# 22  {'name': 'Christian Nørgaard', 'slug': 'christ...    True    block
# 23  {'name': 'Yoane Wissa', 'slug': 'yoane-wissa',...    True     miss
# 24  {'name': 'Frank Onyeka', 'firstName': '', 'las...    True     save
# 25  {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True    block
# 26  {'name': 'Bryan Mbeumo', 'slug': 'bryan-mbeumo...    True    block
# 27  {'name': 'Mike Trésor', 'slug': 'mike-tresor',...   False     miss
# 28  {'name': 'Neal Maupay', 'slug': 'neal-maupay',...    True     miss
#
#              situation               playerCoordinates    bodyPart  \
# 0              regular   {'x': 9.2, 'y': 42.5, 'z': 0}  right-foot
# 1              regular  {'x': 19.9, 'y': 43.1, 'z': 0}  right-foot
# 2              regular  {'x': 24.1, 'y': 53.8, 'z': 0}  right-foot
# 3            free-kick    {'x': 22, 'y': 33.3, 'z': 0}   left-foot
# 4           fast-break   {'x': 9.8, 'y': 54.4, 'z': 0}   left-foot
# 5             assisted  {'x': 12.7, 'y': 58.3, 'z': 0}  right-foot
# 6              regular  {'x': 15.5, 'y': 58.8, 'z': 0}  right-foot
# 7              regular   {'x': 9.1, 'y': 33.4, 'z': 0}  right-foot
# 8             assisted  {'x': 18.2, 'y': 56.3, 'z': 0}   left-foot
# 9               corner  {'x': 13.4, 'y': 31.6, 'z': 0}   left-foot
# 10            assisted  {'x': 20.3, 'y': 23.9, 'z': 0}  right-foot
# 11            assisted  {'x': 18.8, 'y': 57.1, 'z': 0}  right-foot
# 12  throw-in-set-piece  {'x': 10.1, 'y': 51.9, 'z': 0}  right-foot
# 13            assisted  {'x': 10.4, 'y': 47.5, 'z': 0}  right-foot
# 14            assisted  {'x': 20.5, 'y': 57.1, 'z': 0}  right-foot
# 15            assisted  {'x': 23.5, 'y': 40.4, 'z': 0}  right-foot
# 16              corner   {'x': 4.7, 'y': 47.2, 'z': 0}        head
# 17          fast-break  {'x': 17.9, 'y': 56.9, 'z': 0}   left-foot
# 18              corner     {'x': 5, 'y': 59.6, 'z': 0}  right-foot
# 19            assisted  {'x': 21.4, 'y': 51.1, 'z': 0}  right-foot
# 20            assisted     {'x': 2.1, 'y': 45, 'z': 0}   left-foot
# 21              corner  {'x': 11.1, 'y': 43.1, 'z': 0}        head
# 22            assisted     {'x': 7.5, 'y': 60, 'z': 0}  right-foot
# 23            assisted   {'x': 7.7, 'y': 42.1, 'z': 0}        head
# 24            assisted   {'x': 8.4, 'y': 57.9, 'z': 0}        head
# 25  throw-in-set-piece    {'x': 13.7, 'y': 33, 'z': 0}   left-foot
# 26  throw-in-set-piece    {'x': 15, 'y': 33.4, 'z': 0}  right-foot
# 27             regular  {'x': 16.5, 'y': 63.7, 'z': 0}   left-foot
# 28           set-piece  {'x': 12.2, 'y': 57.1, 'z': 0}  right-foot
#
#    goalMouthLocation            goalMouthCoordinates        xg       id  ...  \
# 0        close-right    {'x': 0, 'y': 41, 'z': 19.4}  0.091848  2276909  ...
# 1         high-right  {'x': 0, 'y': 40.7, 'z': 88.9}  0.056739  2276857  ...
# 2          low-right    {'x': 0, 'y': 45.8, 'z': 19}  0.045445  2276774  ...
# 3         low-centre  {'x': 0, 'y': 48.8, 'z': 13.9}  0.054710  2276661  ...
# 4              right   {'x': 0, 'y': 38.8, 'z': 4.2}  0.918136  2276595  ...
# 5         low-centre    {'x': 0, 'y': 51.2, 'z': 19}  0.198040  2276580  ...
# 6           low-left    {'x': 0, 'y': 52.4, 'z': 19}  0.060968  2276453  ...
# 7               high  {'x': 0, 'y': 50.3, 'z': 63.9}  0.091535  2276435  ...
# 8          high-left  {'x': 0, 'y': 54.2, 'z': 30.4}  0.102739  2276413  ...
# 9          high-left  {'x': 0, 'y': 57.8, 'z': 81.9}  0.050490  2276242  ...
# 10        low-centre    {'x': 0, 'y': 50.3, 'z': 19}  0.026666  2276208  ...
# 11        high-right  {'x': 0, 'y': 46.2, 'z': 24.1}  0.077854  2275996  ...
# 12       high-centre    {'x': 0, 'y': 51, 'z': 25.3}  0.239832  2275935  ...
# 13        low-centre  {'x': 0, 'y': 50.1, 'z': 17.1}  0.380608  2275912  ...
# 14              left   {'x': 0, 'y': 67.2, 'z': 5.6}  0.045502  2275907  ...
# 15       close-right   {'x': 0, 'y': 41.2, 'z': 6.9}  0.028283  2275858  ...
# 16             right   {'x': 0, 'y': 34.1, 'z': 9.7}  0.181350  2275794  ...
# 17        low-centre   {'x': 0, 'y': 48.4, 'z': 8.9}  0.123516  2275744  ...
# 18         high-left  {'x': 0, 'y': 61.8, 'z': 87.5}  0.061177  2275716  ...
# 19         low-right   {'x': 0, 'y': 46.6, 'z': 2.8}  0.180646  2275711  ...
# 20          low-left   {'x': 0, 'y': 53.5, 'z': 2.5}  0.727470  2275673  ...
# 21         low-right   {'x': 0, 'y': 46.4, 'z': 8.9}  0.023890  2275637  ...
# 22        low-centre    {'x': 0, 'y': 50.2, 'z': 19}  0.140583  2275643  ...
# 23             right    {'x': 0, 'y': 0.5, 'z': 4.2}  0.092887  2275639  ...
# 24         low-right   {'x': 0, 'y': 46.6, 'z': 8.2}  0.083032  2275576  ...
# 25          low-left      {'x': 0, 'y': 53, 'z': 19}  0.084137  2275546  ...
# 26        low-centre    {'x': 0, 'y': 49.5, 'z': 19}  0.024894  2275536  ...
# 27       close-right   {'x': 0, 'y': 43.5, 'z': 1.4}  0.039577  2275451  ...
# 28        close-left   {'x': 0, 'y': 57.5, 'z': 5.6}  0.144955  2275368  ...
#
#     addedTime  timeSeconds                                               draw  \
# 0         7.0         5799  {'start': {'x': 42.5, 'y': 9.2}, 'end': {'x': ...
# 1         2.0         5502  {'start': {'x': 43.1, 'y': 19.9}, 'end': {'x':...
# 2         NaN         5194  {'start': {'x': 53.8, 'y': 24.1}, 'end': {'x':...
# 3         NaN         4726  {'start': {'x': 33.3, 'y': 22}, 'block': {'x':...
# 4         NaN         4465  {'start': {'x': 54.4, 'y': 9.8}, 'end': {'x': ...
# 5         NaN         4408  {'start': {'x': 58.3, 'y': 12.7}, 'block': {'x...
# 6         NaN         3872  {'start': {'x': 58.8, 'y': 15.5}, 'block': {'x...
# 7         NaN         3824  {'start': {'x': 33.4, 'y': 9.1}, 'end': {'x': ...
# 8         NaN         3700  {'start': {'x': 56.3, 'y': 18.2}, 'end': {'x':...
# 9         NaN         3064  {'start': {'x': 31.6, 'y': 13.4}, 'end': {'x':...
# 10        NaN         2920  {'start': {'x': 23.9, 'y': 20.3}, 'block': {'x...
# 11        1.0         2716  {'start': {'x': 57.1, 'y': 18.8}, 'block': {'x...
# 12        NaN         2536  {'start': {'x': 51.9, 'y': 10.1}, 'block': {'x...
# 13        NaN         2435  {'start': {'x': 47.5, 'y': 10.4}, 'block': {'x...
# 14        NaN         2434  {'start': {'x': 57.1, 'y': 20.5}, 'block': {'x...
# 15        NaN         2257  {'start': {'x': 40.4, 'y': 23.5}, 'end': {'x':...
# 16        NaN         1995  {'start': {'x': 47.2, 'y': 4.7}, 'end': {'x': ...
# 17        NaN         1796  {'start': {'x': 56.9, 'y': 17.9}, 'block': {'x...
# 18        NaN         1685  {'start': {'x': 59.6, 'y': 5}, 'end': {'x': 38...
# 19        NaN         1635  {'start': {'x': 51.1, 'y': 21.4}, 'block': {'x...
# 20        NaN         1469  {'start': {'x': 45, 'y': 2.1}, 'end': {'x': 46...
# 21        NaN         1357  {'start': {'x': 43.1, 'y': 11.1}, 'block': {'x...
# 22        NaN         1333  {'start': {'x': 60, 'y': 7.5}, 'block': {'x': ...
# 23        NaN         1332  {'start': {'x': 42.1, 'y': 7.7}, 'block': {'x'...
# 24        NaN         1044  {'start': {'x': 57.9, 'y': 8.4}, 'block': {'x'...
# 25        NaN          868  {'start': {'x': 33, 'y': 13.7}, 'block': {'x':...
# 26        NaN          866  {'start': {'x': 33.4, 'y': 15}, 'block': {'x':...
# 27        NaN          568  {'start': {'x': 63.7, 'y': 16.5}, 'end': {'x':...
# 28        NaN           85  {'start': {'x': 57.1, 'y': 12.2}, 'end': {'x':...
#
#    reversedPeriodTime  reversedPeriodTimeSeconds  periodTimeSeconds  \
# 0                   1                        501                399
# 1                   1                        798                102
# 2                   4                        206               2494
# 3                  12                        674               2026
# 4                  16                        935               1765
# 5                  17                        992               1708
# 6                  26                       1528               1172
# 7                  27                       1576               1124
# 8                  29                       1700               1000
# 9                  39                       2336                364
# 10                 42                       2480                220
# 11                  1                       2684                 16
# 12                  3                        164               2536
# 13                  5                        265               2435
# 14                  5                        266               2434
# 15                  8                        443               2257
# 16                 12                        705               1995
# 17                 16                        904               1796
# 18                 17                       1015               1685
# 19                 18                       1065               1635
# 20                 21                       1231               1469
# 21                 23                       1343               1357
# 22                 23                       1367               1333
# 23                 23                       1368               1332
# 24                 28                       1656               1044
# 25                 31                       1832                868
# 26                 31                       1834                866
# 27                 36                       2132                568
# 28                 44                       2615                 85
#
#     incidentType goalType    xgot                blockCoordinates
# 0           shot      NaN     NaN                             NaN
# 1           shot      NaN     NaN                             NaN
# 2           shot  regular  0.3436                             NaN
# 3           shot      NaN  0.0493     {'x': 1.4, 'y': 48, 'z': 0}
# 4           shot      NaN     NaN                             NaN
# 5           shot      NaN     NaN   {'x': 9.8, 'y': 56.1, 'z': 0}
# 6           shot      NaN     NaN  {'x': 13.3, 'y': 57.2, 'z': 0}
# 7           shot      NaN     NaN                             NaN
# 8           shot  regular  0.6579                             NaN
# 9           shot      NaN     NaN                             NaN
# 10          shot      NaN     NaN   {'x': 7.9, 'y': 39.7, 'z': 0}
# 11          shot      NaN  0.3528   {'x': 2.4, 'y': 50.7, 'z': 0}
# 12          shot      NaN  0.1511   {'x': 2.2, 'y': 51.1, 'z': 0}
# 13          shot      NaN  0.1861   {'x': 1.8, 'y': 49.6, 'z': 0}
# 14          shot      NaN     NaN   {'x': 9.2, 'y': 48.4, 'z': 0}
# 15          shot      NaN     NaN                             NaN
# 16          shot      NaN     NaN                             NaN
# 17          shot      NaN  0.0597   {'x': 2.4, 'y': 50.9, 'z': 0}
# 18          shot      NaN     NaN                             NaN
# 19          shot      NaN     NaN   {'x': 1.5, 'y': 52.2, 'z': 0}
# 20          shot  regular  0.9561                             NaN
# 21          shot      NaN  0.2615   {'x': 1.6, 'y': 48.7, 'z': 0}
# 22          shot      NaN     NaN   {'x': 2.5, 'y': 53.2, 'z': 0}
# 23          shot      NaN     NaN   {'x': 6.8, 'y': 59.4, 'z': 0}
# 24          shot      NaN  0.3740   {'x': 0.5, 'y': 51.6, 'z': 0}
# 25          shot      NaN     NaN  {'x': 10.9, 'y': 35.9, 'z': 0}
# 26          shot      NaN     NaN  {'x': 12.8, 'y': 35.9, 'z': 0}
# 27          shot      NaN     NaN                             NaN
# 28          shot      NaN     NaN                             NaN
#
# [29 rows x 21 columns]
